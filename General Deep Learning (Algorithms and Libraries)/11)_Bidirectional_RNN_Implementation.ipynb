# %%
from tensorflow.keras.datasets import imdb
from tensorflow.keras.utils import pad_sequences
import warnings
warnings.filterwarnings('ignore')

features = 2000
max_len = 50
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=features)
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

# %%
from keras.models import Sequential
from keras.layers import Embedding, Bidirectional, SimpleRNN, Dense

embedding_dim = 128
hidden_units = 64

model = Sequential()
model.add(Embedding(features, embedding_dim, input_length=max_len))
model.add(Bidirectional(SimpleRNN(hidden_units)))
model.add(Dense(1, activation='sigmoid'))
model.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

# %%
batch_size = 32
epochs = 5
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 49ms/step - accuracy: 0.6215 - loss: 0.6278 - val_accuracy: 0.7680 - val_loss: 0.4863
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 41ms/step - accuracy: 0.8075 - loss: 0.4275 - val_accuracy: 0.7842 - val_loss: 0.4624
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 45s 46ms/step - accuracy: 0.8632 - loss: 0.3207 - val_accuracy: 0.7922 - val_loss: 0.5172
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 42ms/step - accuracy: 0.9167 - loss: 0.2137 - val_accuracy: 0.7584 - val_loss: 0.6196
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 41ms/step - accuracy: 0.9532 - loss: 0.1307 - val_accuracy: 0.7232 - val_loss: 0.8039

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print('Test accuracy:', accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.7168 - loss: 0.8207
# Test accuracy: 0.7232400178909302
