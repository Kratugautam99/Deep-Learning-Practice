# %%
import spacy
from sklearn.metrics.pairwise import cosine_similarity
# !python -m spacy download en_core_web_lg
nlp = spacy.load("en_core_web_lg")
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 3.6 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
doc = nlp("Sleeping Dogs is an Awesome Game, Set in HoNgKoNg.")
for token in doc:
    print(token.text, "Vector:", token.has_vector, "OOV:", token.is_oov)
# Out:
# Sleeping Vector: True OOV: False
# Dogs Vector: True OOV: False
# is Vector: True OOV: False
# an Vector: True OOV: False
# Awesome Vector: True OOV: False
# Game Vector: True OOV: False
# , Vector: True OOV: False
# Set Vector: True OOV: False
# in Vector: True OOV: False
# HoNgKoNg Vector: False OOV: True
# . Vector: True OOV: False

# %%
print(doc[0].vector.shape)
base_token = nlp("Linux")
doc = nlp("Burger is a Junk Food and Windows is an OS better than Mac OS.")
for token in doc:
    print(f"{token.text} <-> {base_token.text}:", token.similarity(base_token))
# Out:
# (300,)
# Burger <-> Linux: 0.08997262269258499
# is <-> Linux: 0.1435224562883377
# a <-> Linux: 0.15444694459438324
# Junk <-> Linux: 0.1947115659713745
# Food <-> Linux: 0.09244059771299362
# and <-> Linux: 0.11156834661960602
# Windows <-> Linux: 0.5502997636795044
# is <-> Linux: 0.1435224562883377
# an <-> Linux: 0.10838944464921951
# OS <-> Linux: 0.5637728571891785
# better <-> Linux: 0.23426367342472076
# than <-> Linux: 0.13640256226062775
# Mac <-> Linux: 0.6147553324699402
# OS <-> Linux: 0.5637728571891785
# . <-> Linux: 0.18331876397132874

# %%
king = nlp.vocab["king"].vector
man = nlp.vocab["man"].vector
woman = nlp.vocab["woman"].vector
queen = nlp.vocab["queen"].vector
result = king - man + woman
cosine_similarity([result], [queen])
# Out:
# array([[0.78808445]], dtype=float32)
